# %%
from huggingface_hub import InferenceClient
from huggingface_hub import login
from dotenv import load_dotenv
import os

# Carrega as variáveis do arquivo .env
load_dotenv()
hf_token = os.getenv("HUGGINGFACE_TOKEN")
login(token=hf_token)

# %%
client = InferenceClient(
    provider="hf-inference",
    api_key=hf_token,
)

# %%
result = client.translation(
    text="Меня зовут Вольфганг и я живу в Берлине",
    model="facebook/nllb-200-distilled-600M"
)

print(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/hf-inference/models/facebook/nllb-200-distilled-600M
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = client.translation(
#       2     text="Меня зовут Вольфганг и я живу в Берлине",
#       3     model="facebook/nllb-200-distilled-600M"
#       4 )
#       6 print(result)
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:2975, in InferenceClient.translation(self, text, model, src_lang, tgt_lang, clean_up_tokenization_spaces, truncation, generate_parameters)
#    2961 provider_helper = get_provider_helper(self.provider, task="translation")
#    2962 request_parameters = provider_helper.prepare_request(
#    2963     inputs=text,
#    2964     parameters={
#    (...)   2973     api_key=self.token,
#    2974 )
# -> 2975 response = self._inner_post(request_parameters)
#    2976 return TranslationOutput.parse_obj_as_list(response)[0]
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:321, in InferenceClient._inner_post(self, request_parameters, stream)
#     318         raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     320 try:
# --> 321     hf_raise_for_status(response)
#     322     return response.iter_lines() if stream else response.content
#     323 except HTTPError as error:
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:481, in hf_raise_for_status(response, endpoint_name)
#     477     raise _format(HfHubHTTPError, message, response) from e
#     479 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     480 # as well (request id and/or server error message)
# --> 481 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/hf-inference/models/facebook/nllb-200-distilled-600M (Request ID: Root=1-67db5a55-0c819896730c9994320ab2d6;532b921a-81e8-43c0-8399-77eba94b211a)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.

# %% [markdown]
# ## Local Model

# %%
from transformers import pipeline

pipe = pipeline("translation_en_to_ptbr", model="facebook/nllb-200-distilled-600M")
pipe("Let's go to france and see the eiffel tower")
