# %%
from transformers import pipeline
from huggingface_hub import login

# %% [markdown]
# ## 1. Select and Install Huggie Face model

# %%
from dotenv import load_dotenv
import os

# Carrega as variáveis do arquivo .env
load_dotenv()
# Out:
# True

# %%
hf_token = os.getenv("HUGGINGFACE_TOKEN")

# %%
login(token=hf_token)

# %%
print("Token carregado:", hf_token is not None)
# Out:
# Token carregado: True

# %% [markdown]
# ## 2. Inference DeepSeek SeqToSeq

# %%
from huggingface_hub import InferenceClient

# %%
client = InferenceClient(
    provider="together",
    api_key=hf_token
)

# %%
messages = [
    {
        "role": "user",
        "content": "What is the capital of France?"
    }
]

completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-R1", 
    messages=messages, 
    max_tokens=500
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/together/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[31], line 8
#       1 messages = [
#       2     {
#       3         "role": "user",
#       4         "content": "What is the capital of France?"
#       5     }
#       6 ]
# ----> 8 completion = client.chat.completions.create(
#       9     model="deepseek-ai/DeepSeek-R1",
#      10     messages=messages,
#      11     max_tokens=500
#      12 )
#      14 print(completion.choices[0].message)
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:956, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     928 parameters = {
#     929     "model": payload_model,
#     930     "frequency_penalty": frequency_penalty,
#    (...)    947     **(extra_body or {}),
#     948 }
#     949 request_parameters = provider_helper.prepare_request(
#     950     inputs=messages,
#     951     parameters=parameters,
#    (...)    954     api_key=self.token,
#     955 )
# --> 956 data = self._inner_post(request_parameters, stream=stream)
#     958 if stream:
#     959     return _stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/inference/_client.py:321, in InferenceClient._inner_post(self, request_parameters, stream)
#     318         raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     320 try:
# --> 321     hf_raise_for_status(response)
#     322     return response.iter_lines() if stream else response.content
#     323 except HTTPError as error:
#
# File ~/.cache/pypoetry/virtualenvs/genai-aogotkCP-py3.11/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:481, in hf_raise_for_status(response, endpoint_name)
#     477     raise _format(HfHubHTTPError, message, response) from e
#     479 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     480 # as well (request id and/or server error message)
# --> 481 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/together/v1/chat/completions (Request ID: Root=1-67db5801-4db0138c30fb3a6500b33172;1ac6ec56-6984-4e09-8c0d-e540da915fd2)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.
